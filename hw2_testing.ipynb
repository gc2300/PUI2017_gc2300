# %%
from __future__ import print_function
import pylab as pl
import os
import json
import sys
import numpy as np
# %pylab inline
pl.rc('font', size=15)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mtakey = sys.argv[1]
bus = sys.argv[2]
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=" + \
        mtakey + "&VehicleMonitoringDetailLevel=calls&LineRef=" + bus
mtakey = os.getenv("mtakey")
url = "http://bustime.mta.info/api/siri/vehicle-monitoring.json?key=" + \
        mtakey + "&VehicleMonitoringDetailLevel=calls&LineRef=B52"

# %%
try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
response = urllib.urlopen(url)
data = response.read().decode("utf-8")
data = json.loads(data)

# %%
print(data)
# Out:
# {u'Siri': {u'ServiceDelivery': {u'SituationExchangeDelivery': [{u'Situations': {u'PtSituationElement': [{u'Description': u'Various BKLYN buses running with delays in both directions due to traffic conditions in the downtown Brooklyn area. Allow additional travel time.', u'Consequences': {u'Consequence': [{u'Condition': u'delayed'}]}, u'Affects': {u'VehicleJourneys': {u'AffectedVehicleJourney': [{u'DirectionRef': u'0', u'LineRef': u'MTABC_B103'}, {u'DirectionRef': u'1', u'LineRef': u'MTABC_B103'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B25'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B25'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B26'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B26'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B37'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B37'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B41'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B41'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B45'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B45'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B52'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B52'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B54'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B54'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B61'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B61'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B62'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B62'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B63'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B63'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B65'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B65'}, {u'DirectionRef': u'0', u'LineRef': u'MTA NYCT_B67'}, {u'DirectionRef': u'1', u'LineRef': u'MTA NYCT_B67'}]}}, u'CreationTime': u'2017-09-26T18:22:11.633-04:00', u'Summary': u'Various BKLYN buses running with delays in both directions due to traffic conditions in the downtown Brooklyn area. Allow additional travel time.', u'PublicationWindow': {u'StartTime': u'2017-09-26T15:30:00.000-04:00'}, u'SituationNumber': u'MTABC_7bbcf59a-20f9-40f2-a978-b32e414cfe67', u'Severity': u'undefined'}]}}], u'ResponseTimestamp': u'2017-09-26T19:57:09.357-04:00', u'VehicleMonitoringDelivery': [{u'VehicleActivity': [{u'RecordedAtTime': u'2017-09-26T19:56:48.000-04:00', u'MonitoredVehicleJourney': {u'OriginRef': u'MTA_504965', u'Bearing': 106.96615, u'VehicleLocation': {u'Latitude': 40.693922, u'Longitude': -73.990411}, u'SituationRef': [{u'SituationSimpleRef': u'MTABC_7bbcf59a-20f9-40f2-a978-b32e414cfe67'}], u'OperatorRef': u'MTA NYCT', u'VehicleRef': u'MTA NYCT_7274', u'ProgressStatus': u'layover', u'BlockRef': u'MTA NYCT_FP_D7-Weekday-SDon_E_FP_59460_B52-137', u'OriginAimedDepartureTime': u'2017-09-26T20:08:00.000-04:00', u'DestinationName': u'DNTWN BKLYN TILLARY ST via GATES', u'DestinationRef': u'MTA_901463', u'JourneyPatternRef': u'MTA_B520048', u'MonitoredCall': {u'StopPointRef': u'MTA_901463', u'StopPointName': u'CADMAN PZ W/TILLARY ST', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91, u'StopsFromCall': 0, u'PresentableDistance': u'at stop', u'DistanceFromCall': 0.0}}, u'VisitNumber': 1}, u'LineRef': u'MTA NYCT_B52', u'FramedVehicleJourneyRef': {u'DataFrameRef': u'2017-09-26', u'DatedVehicleJourneyRef': u'MTA NYCT_FP_D7-Weekday-SDon-114400_B52_135'}, u'PublishedLineName': u'B52', u'Monitored': True, u'OnwardCalls': {u'OnwardCall': [{u'StopPointRef': u'MTA_901463', u'StopPointName': u'CADMAN PZ W/TILLARY ST', u'Extensions': {u'Distances': {u'CallDistanceAlongRoute': 8097.91, u'StopsFromCall': 0, u'PresentableDistance': u'at stop', u'DistanceFromCall': 0.0}}}]}, u'DirectionRef': u'1', u'ProgressRate': u'noProgress'}}, {u'RecordedAtTime': u'2017-09-26T19:56:45.000-04:00', u'MonitoredVehicleJourney': {u'OriginRef': u'MTA_504965', u'Bearing': 186.5663, u'VehicleLocation': {u'Latitude': 40.68923, u'Longitude': -73.924365}, u'SituationRef': [{u'SituationSimpleRef': u'MTAB ...

# %%
bus = "B52"
buses= data['Siri']['ServiceDelivery']['VehicleMonitoringDelivery'][0]['VehicleActivity']
numbus=np.size(buses)
print ("Bus Line : %s"%(bus))
print ("Number of Active Buses : %d" %(numbus))
for i in range(len(buses)):
        lat = buses[i]['MonitoredVehicleJourney']['VehicleLocation']['Latitude']
        lon = buses[i]['MonitoredVehicleJourney']['VehicleLocation']['Longitude']
        print("Bus %s is at latitude %s and longtitude %s" %(i,lat,lon))
# Out:
# Bus Line : B52
# Number of Active Buses : 14
# Bus 0 is at latitude 40.693922 and longtitude -73.990411
# Bus 1 is at latitude 40.68923 and longtitude -73.924365
# Bus 2 is at latitude 40.687909 and longtitude -73.935881
# Bus 3 is at latitude 40.688117 and longtitude -73.934031
# Bus 4 is at latitude 40.696187 and longtitude -73.990982
# Bus 5 is at latitude 40.692452 and longtitude -73.989063
# Bus 6 is at latitude 40.686633 and longtitude -73.946975
# Bus 7 is at latitude 40.699312 and longtitude -73.911252
# Bus 8 is at latitude 40.686159 and longtitude -73.974062
# Bus 9 is at latitude 40.700087 and longtitude -73.911655
# Bus 10 is at latitude 40.690351 and longtitude -73.984583
# Bus 11 is at latitude 40.68786 and longtitude -73.936306
# Bus 12 is at latitude 40.686325 and longtitude -73.969161
# Bus 13 is at latitude 40.686811 and longtitude -73.975664
