# %%
import os
import io
import pandas as pd
import zipfile
import geopandas as  gpd
import numpy as np
from sklearn.cluster import KMeans, DBSCAN
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
import seaborn
import datetime
import requests
import json
import pylab as pl
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#these commands can be run on the shell and get the data with the command wget
#the cell needs to be run only once
# !for ((y=93; y<=99; y+=1)); do wget \
ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp$y\totals.zip; done

# !for ((y=0; y<=1; y+=1)); do wget \
ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=2; y<=9; y+=1)); do wget \
ftp://ftp.census.gov/econ200$y\/CBP_CSV/zbp0$y\totals.zip; done

# !for ((y=10; y<=14; y+=1)); do wget \
ftp://ftp.census.gov/econ20$y\/CBP_CSV/zbp$y\totals.zip; done
# Out:
# --2017-12-11 21:42:54--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp93totals.zip
#            => 'zbp93totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 21:47:59--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp93totals.zip
#   (try: 2) => 'zbp93totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp93totals.zip ... done.
#
# ==> PASV ... done.    ==> RETR zbp93totals.zip ...
# No such file 'zbp93totals.zip'.
#
# --2017-12-11 21:47:59--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
#            => 'zbp94totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:03:00--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
#   (try: 2) => 'zbp94totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:08:02--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp94totals.zip
#   (try: 3) => 'zbp94totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp94totals.zip ... 611524
# ==> PASV ... done.    ==> RETR zbp94totals.zip ... done.
# Length: 611524 (597K) (unauthoritative)
#
# zbp94totals.zip     100%[===================>] 597.19K  1.28MB/s    in 0.5s
#
# 2017-12-11 22:08:04 (1.28 MB/s) - 'zbp94totals.zip' saved [611524]
#
# --2017-12-11 22:08:04--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip
#            => 'zbp95totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:13:08--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip
#   (try: 2) => 'zbp95totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:18:10--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp95totals.zip
#   (try: 3) => 'zbp95totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp95totals.zip ... 625328
# ==> PASV ... done.    ==> RETR zbp95totals.zip ... done.
# Length: 625328 (611K) (unauthoritative)
#
# zbp95totals.zip     100%[===================>] 610.67K  1.00MB/s    in 0.6s
#
# 2017-12-11 22:18:12 (1.00 MB/s) - 'zbp95totals.zip' saved [625328]
#
# --2017-12-11 22:18:12--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp96totals.zip
#            => 'zbp96totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp96totals.zip ... 632625
# ==> PASV ... done.    ==> RETR zbp96totals.zip ... done.
# Length: 632625 (618K) (unauthoritative)
#
# zbp96totals.zip     100%[===================>] 617.80K   973KB/s    in 0.6s
#
# 2017-12-11 22:18:14 (973 KB/s) - 'zbp96totals.zip' saved [632625]
#
# --2017-12-11 22:18:14--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip
#            => 'zbp97totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:23:15--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip
#   (try: 2) => 'zbp97totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:28:20--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp97totals.zip
#   (try: 3) => 'zbp97totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp97totals.zip ... 629368
# ==> PASV ... done.    ==> RETR zbp97totals.zip ... done.
# Length: 629368 (615K) (unauthoritative)
#
# zbp97totals.zip     100%[===================>] 614.62K  1.29MB/s    in 0.5s
#
# 2017-12-11 22:28:22 (1.29 MB/s) - 'zbp97totals.zip' saved [629368]
#
# --2017-12-11 22:28:22--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp98totals.zip
#            => 'zbp98totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:33:27--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp98totals.zip
#   (try: 2) => 'zbp98totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp98totals.zip ... 617784
# ==> PASV ... done.    ==> RETR zbp98totals.zip ... done.
# Length: 617784 (603K) (unauthoritative)
#
# zbp98totals.zip     100%[===================>] 603.30K   772KB/s    in 0.8s
#
# 2017-12-11 22:33:29 (772 KB/s) - 'zbp98totals.zip' saved [617784]
#
# --2017-12-11 22:33:29--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp99totals.zip
#            => 'zbp99totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:38:31--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp99totals.zip
#   (try: 2) => 'zbp99totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:43:35--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp99totals.zip
#   (try: 3) => 'zbp99totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp99totals.zip ... 625814
# ==> PASV ... done.    ==> RETR zbp99totals.zip ... done.
# Length: 625814 (611K) (unauthoritative)
#
# zbp99totals.zip     100%[===================>] 611.15K  1.51MB/s    in 0.4s
#
# 2017-12-11 22:43:37 (1.51 MB/s) - 'zbp99totals.zip' saved [625814]
#
# --2017-12-11 22:43:37--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
#            => 'zbp00totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:48:39--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
#   (try: 2) => 'zbp00totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:53:42--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
#   (try: 3) => 'zbp00totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 22:58:44--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp00totals.zip
#   (try: 4) => 'zbp00totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp00totals.zip ... 628434
# ==> PASV ... done.    ==> RETR zbp00totals.zip ... done.
# Length: 628434 (614K) (unauthoritative)
#
# zbp00totals.zip     100%[===================>] 613.71K  1.18MB/s    in 0.5s
#
# 2017-12-11 22:58:46 (1.18 MB/s) - 'zbp00totals.zip' saved [628434]
#
# --2017-12-11 22:58:46--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip
#            => 'zbp01totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 23:03:47--  ftp://ftp.census.gov/Econ2001_And_Earlier/CBP_CSV/zbp01totals.zip
#   (try: 2) => 'zbp01totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /Econ2001_And_Earlier/CBP_CSV ... done.
# ==> SIZE zbp01totals.zip ... 628815
# ==> PASV ... done.    ==> RETR zbp01totals.zip ... done.
# Length: 628815 (614K) (unauthoritative)
#
# zbp01totals.zip     100%[===================>] 614.08K  1.53MB/s    in 0.4s
#
# 2017-12-11 23:03:49 (1.53 MB/s) - 'zbp01totals.zip' saved [628815]
#
# --2017-12-11 23:03:49--  ftp://ftp.census.gov/econ2002/CBP_CSV/zbp02totals.zip
#            => 'zbp02totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2002/CBP_CSV ... done.
# ==> SIZE zbp02totals.zip ... 620754
# ==> PASV ... done.    ==> RETR zbp02totals.zip ... done.
# Length: 620754 (606K) (unauthoritative)
#
# zbp02totals.zip     100%[===================>] 606.21K  1.53MB/s    in 0.4s
#
# 2017-12-11 23:03:51 (1.53 MB/s) - 'zbp02totals.zip' saved [620754]
#
# --2017-12-11 23:03:51--  ftp://ftp.census.gov/econ2003/CBP_CSV/zbp03totals.zip
#            => 'zbp03totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 23:08:54--  ftp://ftp.census.gov/econ2003/CBP_CSV/zbp03totals.zip
#   (try: 2) => 'zbp03totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2003/CBP_CSV ... done.
# ==> SIZE zbp03totals.zip ... 622790
# ==> PASV ... done.    ==> RETR zbp03totals.zip ... done.
# Length: 622790 (608K) (unauthoritative)
#
# zbp03totals.zip     100%[===================>] 608.19K  1.24MB/s    in 0.5s
#
# 2017-12-11 23:08:56 (1.24 MB/s) - 'zbp03totals.zip' saved [622790]
#
# --2017-12-11 23:08:56--  ftp://ftp.census.gov/econ2004/CBP_CSV/zbp04totals.zip
#            => 'zbp04totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 23:13:59--  ftp://ftp.census.gov/econ2004/CBP_CSV/zbp04totals.zip
#   (try: 2) => 'zbp04totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Error in server response. Closing.
# Retrying.
#
# --2017-12-11 23:19:05--  ftp://ftp.census.gov/econ2004/CBP_CSV/zbp04totals.zip
#   (try: 3) => 'zbp04totals.zip'
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# ^C
# --2017-12-11 23:21:07--  ftp://ftp.census.gov/econ2010/CBP_CSV/zbp10totals.zip
#            => 'zbp10totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /econ2010/CBP_CSV ... done.
# ==> SIZE zbp10totals.zip ... 797534
# ==> PASV ... done.    ==> RETR zbp10totals.zip ... done.
# Length: 797534 (779K) (unauthoritative)
#
# zbp10totals.zip     100%[===================>] 778.84K   506KB/s    in 1.5s
#
# 2017-12-11 23:21:09 (506 KB/s) - 'zbp10totals.zip' saved [797534]
#
# --2017-12-11 23:21:09--  ftp://ftp.census.gov/econ2011/CBP_CSV/zbp11totals.zip
#            => 'zbp11totals.zip'
# Resolving ftp.census.gov... 148.129.75.35
# Connecting to ftp.census.gov|148.129.75.35|:21... connected.

# %% [markdown]
# <br/>

# %%
re = requests.get("http://catalog.civicdashboards.com/dataset/11fd957a-8885-42ef-aa49-5c879ec93fac/resource/28377e88-8a50-428f-807c-40ba1f09159b/download/nyc-zip-code-tabulation-areas-polygons.geojson")

# %%
js = json.loads(re.text)
js
# Out:
# {'features': [{'geometry': {'coordinates': [[[-73.86942457284177,
#        40.74915687096788],
#       [-73.89143129977276, 40.74684466041932],
#       [-73.89507143240859, 40.746465470812154],
#       [-73.8961873786782, 40.74850942518088],
#       [-73.8958395418514, 40.74854687570604],
#       [-73.89525242774397, 40.748306609450246],
#       [-73.89654041085562, 40.75054199814359],
#       [-73.89579868613829, 40.75061972133262],
#       [-73.89652230661434, 40.75438879610903],
#       [-73.88164812188481, 40.75595161704187],
#       [-73.87221855882478, 40.75694324806748],
#       [-73.87167992356792, 40.75398717439604],
#       [-73.8720704651389, 40.753862007052064],
#       [-73.86942457284177, 40.74915687096788]]],
#     'type': 'Polygon'},
#    'properties': {'@id': 'http://nyc.pediacities.com/Resource/PostalCode/11372',
#     'BLDGpostal': 0,
#     'CTY_FIPS': '081',
#     'OBJECTID': 1,
#     'PO_NAME': 'Jackson Heights',
#     'STATE': 'NY',
#     'ST_FIPS': '36',
#     'borough': 'Queens',
#     'latitude': 40.751662187,
#     'longitude': -73.883573184,
#     'postalCode': '11372'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[-73.71132911125308, 40.74947450816085],
#       [-73.7106837407401, 40.75004039450918],
#       [-73.70869392379949, 40.74875836557177],
#       [-73.70713084684176, 40.749582740537946],
#       [-73.70419967936363, 40.750169552569766],
#       [-73.70218528698231, 40.744741887753854],
#       [-73.70308721830736, 40.744547257355144],
#       [-73.70098278625547, 40.73889569923034],
#       [-73.71371033246908, 40.736174704865455],
#       [-73.714741836008, 40.73782936804115],
#       [-73.71567895968894, 40.73962914915626],
#       [-73.71867075939582, 40.74631499057428],
#       [-73.71966142935703, 40.748945236431474],
#       [-73.72082889049311, 40.751173028173014],
#       [-73.72117809110456, 40.75232189224561],
#       [-73.72250622247415, 40.753358470814895],
#       [-73.72270447144122, 40.75373371438336],
#       [-73.72183610276068, 40.75486513130315],
#       [-73.72109289651769, 40.7562813418113],
#       [-73.71775341502477, 40.75534755942338],
#       [-73.71730957335735, 40.75595782995615],
#       [-73.71534601002345, 40.75550893330126],
#       [-73.71553103019596, 40.75506458072391],
#       [-73.71541781535772, 40.7549984440815],
#       [-73.71509806179287, 40.75181177075926],
#       [-73.71132911125308, 40.74947450816085]]],
#     'type': 'Polygon'},
#    'properties': {'@id': 'http://nyc.pediacities.com/Resource/PostalCode/
properties': {'@id': 'http://nyc.pediacities.com/Resource/PostalCode/10282',
#     'BLDGpostal': 0,
#     'CTY_FIPS': '061',
#     'OBJECTID': 262,
#     'PO_NAME': 'New York',
#     'STATE': 'NY',
#     'ST_FIPS': '36',
#     'borough': 'Manhattan',
#     'latitude': 40.716314633,
#     'longitude': -74.015450156,
#     'postalCode': '10282'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %% [markdown]
# ## 1. Load NYC Zipcode Zone

# %%
FilePath = os.getenv("PUIDATA")+"/HW11/"
os.chdir(FilePath)

zipNYC = gpd.read_file("nyc-zip-code-tabulation-areas-polygons.geojson")
# Change ColNames
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# <ipython-input-15-d995572a7710> in <module>()
#       2 os.chdir(FilePath)
#       3
# ----> 4 zipNYC = gpd.read_file("nyc-zip-code-tabulation-areas-polygons.geojson")
#       5 # Change ColNames
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/geopandas/io/file.py in read_file(filename, **kwargs)
#      17     """
#      18     bbox = kwargs.pop('bbox', None)
# ---> 19     with fiona.open(filename, **kwargs) as f:
#      20         crs = f.crs
#      21         if bbox is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/fiona/__init__.py in open(path, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt)
#     163         c = Collection(path, mode, driver=driver, encoding=encoding,
#     164                        layer=layer, vsi=vsi, archive=archive,
# --> 165                        enabled_drivers=enabled_drivers)
#     166     elif mode == 'w':
#     167         if schema:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/fiona/collection.py in __init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, **kwargs)
#     151             if self.mode == 'r':
#     152                 self.session = Session()
# --> 153                 self.session.start(self)
#     154             elif self.mode in ('a', 'w'):
#     155                 self.session = WritingSession()
#
# fiona/ogrext.pyx in fiona.ogrext.Session.start()
#
# fiona/_err.pyx in fiona._err.GDALErrCtxManager.__exit__()
#
# CPLE_OpenFailedError: b'Failed to read GeoJSON data'

# %%
zipNYC = zipNYC.rename(columns={'postalCode': "zipcode"})
zipNYC = zipNYC[['zipcode', 'geometry', 'borough', 'PO_NAME']]
zipNYC.zipcode = pd.to_numeric(zipNYC.zipcode)
zipNYC.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-fcc62078f123> in <module>()
#       7     zipNYC = gpd.GeoDataFrame(re.json())
#       8 zipNYC = zipNYC.rename(columns={'postalCode': "zipcode"})
# ----> 9 zipNYC = zipNYC[['zipcode', 'geometry', 'borough', 'PO_NAME']]
#      10 zipNYC.zipcode = pd.to_numeric(zipNYC.zipcode)
#      11 zipNYC.head()
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/geopandas/geodataframe.py in __getitem__(self, key)
#     396         GeoDataFrame.
#     397         """
# --> 398         result = super(GeoDataFrame, self).__getitem__(key)
#     399         geo_col = self._geometry_column_name
#     400         if isinstance(key, string_types) and key == geo_col:
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['zipcode' 'geometry' 'borough' 'PO_NAME'] not in index"

# %%
def check_zipcode(zipNYC):
    '''
    check_zipcode is consistant or not
    input: dataframe contains zipcode information
    output: numerical unique zipcode list zipcode_list
    '''

    # Unique Zipcode in NYC
    print "# of All Zipcode: ", zipNYC.zipcode.unique().shape[0]
    print "# of Unique Zipcode: ", zipNYC.shape[0]

    # (Numeric) NYC Zipcode LIST
    zipNYCList = pd.to_numeric(zipNYC.zipcode).values

    # (Numeric NYC Zipcode UNIQUE LIST
    zipNYCList_Unique = np.unique(zipNYCList)
    
    return zipNYCList_Unique,zipNYCList

zipNYCList_Unique,zipNYCList = check_zipcode(zipNYC)
# Out:
# # of All Zipcode:  247
# # of Unique Zipcode:  262

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 2. Load and Merge Census Business Data

# %%
# Create a copy of zipNYC
zip_merged = zipNYC.copy()

# create curated year list
year = datetime.datetime.today().year
YEARS = map(str,range(year-2, year - 23, -1))
YEARS = map(lambda x:x[2:4],YEARS)

def merged_business(YEARS, zip_merged,zipNYCList):
    '''
    merged all the business files
    
    input: year range and original zipcode list
    output: CB
    '''
    
    # Merge(1994-2014)
    for year in YEARS:
        # Name
        fname = str('zbp' + year + 'totals.zip')
        colname_EST = str('EST' + year)  # colname of new adding column
        # Load
        zf = zipfile.ZipFile(fname)
        df = pd.read_csv(zf.open(fname.replace('.zip','.txt')))
        df.columns = map(str.upper, df.columns) # since there are cases 'ZIP' and 'EST' are lowercases.
        # Filter
        CB_NYC = df[np.in1d(df.ZIP, zipNYCList)].loc[:,['ZIP','EST']]
        # Merge
        CB_NYC = CB_NYC.rename(columns={'ZIP': 'zipcode'})
        zip_merged = pd.merge(zip_merged, CB_NYC, on='zipcode')
        # Colname
        zip_merged = zip_merged.rename(columns={"EST": colname_EST})

    # create CB to store merged data
    CB = zip_merged
    return CB

CB = merged_business(YEARS, zip_merged,zipNYCList)

# %% [markdown]
# ## 3. Standardlized CB

# %%
CB_mean = CB.iloc[:,range(4,25)].mean(axis=1)
CB_std = CB.iloc[:,range(4,25)].std(axis=1)
CB.iloc[:,range(4,25)] = CB.iloc[:,range(4,25)].apply(lambda x: (x- CB_mean) / CB_std)

# %%
CB.head(2)
# Out:
#    zipcode                                           geometry borough  \
# 0    11372  POLYGON ((-73.86942457284175 40.74915687096787...  Queens
# 1    11004  POLYGON ((-73.71068374074007 40.75004039450917...  Queens
#
#            PO_NAME     EST14     EST13     EST12     EST11     EST10  \
# 0  Jackson Heights  1.693350  1.637516  1.420382  0.942687  0.831018
# 1        Glen Oaks  1.577923  1.167706  1.167706  0.301694  0.620751
#
#       EST09    ...        EST03     EST02     EST01     EST00     EST99  \
# 0  0.477400    ...     0.161004 -0.198818 -0.540029 -0.533825 -0.738551
# 1  0.803069    ...     0.575171 -0.062943 -0.518739 -1.202433 -1.339172
#
#       EST98     EST97     EST96     EST95     EST94
# 0 -0.893647 -1.154208 -1.259673 -1.607088 -1.650515
# 1 -0.974535 -1.065695 -1.794968 -1.248013 -0.974535
#
# [2 rows x 25 columns]

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 4. KMeans

# %%
mod_km = KMeans(n_clusters=4, init='k-means++', n_init=10, max_iter=500, tol=0.0001, 
                verbose=0, random_state=None).fit(CB.iloc[:,range(4,25)])

# %%
centers = mod_km.cluster_centers_

# %% [markdown]
# ### For Example, set EST94 and EST14 as x/y axis and plot cluster centers

# %%
pl.figure(figsize=(8,8))
pl.scatter(CB[mod_km.labels_ == 0].iloc[:,4], CB[mod_km.labels_ == 0].iloc[:,24], \
           color='lightblue', alpha=0.3, label="Cluster 1")
pl.scatter(centers[0][0], centers[0][-1], marker='o', s=100, color='blue', label="Cluster 1 Center")

pl.scatter(CB[mod_km.labels_ == 1].iloc[:,4], CB[mod_km.labels_ == 1].iloc[:,24], \
           color='red', alpha=0.3, label="Cluster 2")
pl.scatter(centers[1][0], centers[1][-1], marker='o', s=100, color='red', label="Cluster 2 Center")

pl.scatter(CB[mod_km.labels_ == 2].iloc[:,4], CB[mod_km.labels_ == 2].iloc[:,24], \
           color='green', alpha=0.3, label="Cluster 3")
pl.scatter(centers[2][0], centers[2][-1], marker='o', s=100, color='green', label="Cluster 3 Center")

pl.scatter(CB[mod_km.labels_ == 3].iloc[:,4], CB[mod_km.labels_ == 3].iloc[:,24], \
           color='purple', alpha=0.3, label="Cluster 4")
pl.scatter(centers[3][0], centers[3][-1], marker='o', s=100, color='purple', label="Cluster 4 Center")

# pl.scatter(CB[mod_km.labels_ == 4].iloc[:,4], CB[mod_km.labels_ == 4].iloc[:,24], \
#            color='orange', alpha=0.3, label="Cluster 5")
# pl.scatter(centers[4][0], centers[4][-1], marker='*', s=100, color='orange', label="Cluster 5 Center")

pl.xlabel("EST94")
pl.ylabel("EST14")
pl.title("KMeans Cluster: The Number Of ESTABLISHMENTS")
pl.legend(fontsize=10, loc='best')

# %% [markdown]
# #### KMeans Cluster for EST94~EST14 has shown in above plot. The Figure that data points from different clusters gather aroud their own cluster centers with a little overlap.

# %% [markdown]
# <br/><br/>

# %% [markdown]
# ## 5. DBSCAN

# %%
mod_DBSCAN = DBSCAN(min_samples=4).fit(CB.iloc[:,range(4,25)])

# %%
unique(mod_DBSCAN.labels_)
# Out:
# array([-1,  0,  1,  2,  3])

# %% [markdown]
# ### DBSCAN: 5 Clusters In Total

# %% [markdown]
# ## 6. Hierarchical Clustering

# %%
Z = linkage(CB.iloc[:,range(4,25)], 'ward')

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
pl.show()

# %% [markdown]
# ### Plot above shows the result of hierarchical clustering.

# %%
HC_label = fcluster(Z, 4, criterion='maxclust')

# %% [markdown]
# <br/><br/>
# ## 7. Plot

# %%
CB2 = CB.copy()
CB2['km'] = mod_km.labels_
CB2['DBSCAN'] = mod_DBSCAN.labels_
CB2['HC'] = HC_label
CB2['HC_'] = CB2.HC.replace([1,4],[4,1])

# %%
f, (ax1, ax2, ax3) = pl.subplots(1,3,figsize=(60,20))
CB2.plot(colormap='OrRd', column='km', ax=ax1, categorical=True, k=4)
ax1.set_title("KMeans, k=4", fontsize=50)
CB2.plot(colormap='OrRd', column='HC_', ax=ax2, categorical=True, k=4)
ax2.set_title("Hierarchical Clustering, k=4", fontsize=50)
CB2.plot(colormap='OrRd', column='DBSCAN', ax=ax3, categorical=True, k=5)
ax3.set_title("DBSCAN, k=5", fontsize=50)

# %% [markdown]
# ### Above Plots shows cluster result of three clustering methods (k-means, Hierarchical Clustering and DBSCN)

# %% [markdown]
# <br/><br/>
# ## 8. Interpretation and Exploration

# %% [markdown]
# Overall, the clustering results are similar to each other. What I think is really interesting is the results show that the pattern of some area in manhattan is similar in south brooklyn

# %%
#@Review: Insufficeitn Comparison and interpretation!
